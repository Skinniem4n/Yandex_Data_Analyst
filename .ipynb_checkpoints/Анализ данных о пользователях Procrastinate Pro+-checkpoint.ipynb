# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Егор, привет!</b> Мы рады тебя видеть на территории код-ревьюеров. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У тебя неограниченное количество попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Анализ данных о пользователях Procrastinate Pro+
#
# Несколько прошлых месяцев наш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого.
#
# **Цель нашего исследования** - разобраться в причинах неокупаемости рекламных кампаний, и, таким образом, помочь компании выйти в плюс.
#
# - Изучить, как люди пользуются продуктом;
# - Изучить, когда пользователи начинают покупать;
# - Понять, сколько денег приносит каждый клиент;
# - Понять, когда окупается каждый клиент;
# - Выяснить, какие факторы отрицательно влияют на привлечение пользователей.
#
# **Ход исследования**
#
# У нас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# Исследование пройдет в 4 этапа:
#
# - Загрузка данных и подготовка их к анализу;
# - Исследовательский анализ данных. Посмотрим количество трафика и долю платящих пользователей в разных разбивках;
# - Маркетинг. Посчитаем общие расходы на рекламу и узнаем, сколько в среднем стоит привлечение одного пользователя;
# - Оценка окупаемости рекламы. Исследуем общую окупаемость релкамы, а также окупаемость в разных разбивках;
# - Вывод. Напишем общий вывод и рекомендации маркетингу.
#
# Описание данных:
#
# Таблица `visits_log_short` (лог сервера с информацией о посещениях сайта):
# - User Id — уникальный идентификатор пользователя
# - Device — категория устройства пользователя
# - Session start — дата и время начала сессии
# - Session End — дата и время окончания сессии
# - Channel — идентификатор рекламного источника, из которого пришел пользователь
# - Region - страна пользователя
#
# Таблица `orders_log_short` (информация о заказах):
#
# - User Id — уникальный id пользователя, который сделал заказ
# - Event Dt — дата и время покупки
# - Revenue — выручка
#
# Таблица `costs_short` (информация о затратах на маркетинг):
#
# - Channel — идентификатор рекламного источника
# - Dt — дата
# - Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# # Шаг 1. Загрузим данные и подготовим их к анализу
# Загрузим данные о визитах, заказах и расходах в переменные. Оптимизируем данные для анализа. Убедимся, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv.
#  -   /datasets/orders_info_short.csv.
#  -   /datasets/costs_info_short.csv.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import numpy as np

# %%
visits = pd.read_csv('C:\\Users\\Skinnyman\\Pictures\\datasets\\visits_info.csv')
orders = pd.read_csv('C:\\Users\\Skinnyman\\Pictures\\datasets\\orders_info.csv')
costs = pd.read_csv('C:\\Users\\Skinnyman\\Pictures\\datasets\\costs_info.csv')

# %% [markdown]
# Начнем с `visits`. Посмотрим на структуру, при необходимости проведем предобработку.

# %%
visits.head(5)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.sample(5)
# Out:
#              User Id         Region   Device             Channel  \
# 63621   216255843651  United States      Mac        MediaTornado
# 46858   316398993849  United States  Android             organic
# 119725   56625553301  United States   iPhone              TipTop
# 165439  797600867442  United States   iPhone             organic
# 270615  512810411347             UK      Mac  OppleCreativeMedia
#
#               Session Start          Session End
# 63621   2019-07-03 02:48:33  2019-07-03 03:39:43
# 46858   2019-06-19 17:09:41  2019-06-19 17:09:41
# 119725  2019-08-23 16:59:57  2019-08-23 18:04:19
# 165439  2019-09-29 01:03:17  2019-09-29 02:20:50
# 270615  2019-08-29 22:45:37  2019-08-29 23:30:31

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
visits.describe()
# Out:
#             User Id
# count  3.099010e+05
# mean   4.997664e+11
# std    2.887899e+11
# min    5.993260e+05
# 25%    2.493691e+11
# 50%    4.989906e+11
# 75%    7.495211e+11
# max    9.999996e+11

# %% [markdown]
# Приведем столбцы к нужному стилю и поменяем тип данных с толбцах `session_start` и `session_end` на `datetime`.

# %%
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
# проверим наличие дублей

visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет - переходим к следующей таблице.

# %%
orders.head(5)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.sample(5)
# Out:
#             User Id             Event Dt  Revenue
# 30904  651404964654  2019-07-11 05:01:42     4.99
# 8871   820909014233  2019-07-22 20:19:12     4.99
# 14909  732666979907  2019-08-28 09:21:43     4.99
# 12872  131368224016  2019-08-17 22:09:41     4.99
# 4663   787357975005  2019-06-24 21:28:31     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders.describe()
# Out:
#             User Id       Revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000

# %% [markdown]
# Проделаем ту же работу - переименуем столбцы и поменяем типы данных там, где нужно.

# %%
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
# проверяем наличий дублей

orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов также нет. Переходим к последнему датафрейму.

# %%
costs.head(5)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.sample(5)
# Out:
#               dt             Channel   costs
# 1374  2019-08-23  OppleCreativeMedia  15.000
# 853   2019-09-11             YRabbit   3.360
# 1640  2019-05-21      lambdaMediaAds  18.400
# 406   2019-06-16      RocketSuperAds  13.455
# 913   2019-05-14          AdNonSense  35.700

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.describe()
# Out:
#              costs
# count  1800.000000
# mean     58.609611
# std     107.740223
# min       0.800000
# 25%       6.495000
# 50%      12.285000
# 75%      33.600000
# max     630.000000

# %% [markdown]
# Также приводим столбцы к правильному формату и менаем типы данных.

# %%
costs.columns = costs.columns.str.lower().str.replace(' ', '_')
costs['dt'] = pd.to_datetime(costs['dt'])

costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB

# %%
# проверка на дубли

costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим, есть ли ошибки в столбцах `session_start` и `session_end`.

# %%
visits[visits['session_start'] > visits['session_end']]
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, session_start, session_end]
# Index: []

# %% [markdown]
# Отлично, в данных нет случаев, когда окончание сессии указано раньше начала.

# %%
visits[visits['session_start'] == visits['session_end']]
# Out:
#              user_id         region   device             channel  \
# 100     172991619815  United States  Android             organic
# 396      70966634103  United States   iPhone            FaceBoom
# 6418    237822984474  United States   iPhone            FaceBoom
# 7658    691394091917  United States   iPhone             organic
# 8549    851693391616  United States       PC              TipTop
# ...              ...            ...      ...                 ...
# 298392  869320035302         France      Mac          AdNonSense
# 300057  170196678386         France       PC             organic
# 302612   14571051192        Germany   iPhone             LeapBob
# 302852  716198028632             UK  Android  OppleCreativeMedia
# 303584  459066115384         France  Android             organic
#
#              session_start         session_end
# 100    2019-05-01 23:30:20 2019-05-01 23:30:20
# 396    2019-05-01 10:09:06 2019-05-01 10:09:06
# ...

# %% [markdown]
# В 163 случая совпадения времени начала и окончания сессии я готов поверить. Скорее всего, это случаи, когда пользователи зашли в приложение по ошибке.

# %%
# Тут проверки на минимальные и максимальные значения начала и окончания сессий. Всё ок

#display(visits['session_end'].min())
#display(visits['session_end'].max())
#display(visits['session_start'].min())
#visits['session_start'].max()

# %% [markdown]
# Наконец, посмотрим, есть ли ошибки в численных данных, которые по логике могут быть только ненулевыми

# %%
display(visits[visits['user_id'] <= 0])
display(orders[orders['revenue'] <= 0])
display(orders[orders['user_id'] <= 0])
costs[costs['costs'] <= 0]
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, session_start, session_end]
# Index: []
# Empty DataFrame
# Columns: [user_id, event_dt, revenue]
# Index: []
# Empty DataFrame
# Columns: [user_id, event_dt, revenue]
# Index: []
# Empty DataFrame
# Columns: [dt, channel, costs]
# Index: []

# %% [markdown]
# Отлично, дубликатов и ошибок нет. Данные готовы для анализа.

# %% [markdown]
# # Шаг 2. Зададим функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми мы познакомились в теоретических уроках.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs, event_names=[]):

    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'])
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(
        0
    )
    
    return profiles


# функция для расчёта удержания

def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    dimensions = ['payer'] + dimensions
    
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'})
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)
        result = result.div(result['cohort_size'], axis = 0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result
    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    return result_raw, result_grouped, result_in_time


# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    if 'cohort' in dimensions: 
        dimensions = []

    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return result_raw, result_grouped, result_in_time


# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes

        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        roi = result.div(cac['cac'], axis=0)

        roi = roi[~roi['cohort_size'].isin([np.inf])]

        roi['cohort_size'] = cohort_sizes

        roi['cac'] = cac['cac']

        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    if 'cohort' in dimensions:
        dimensions = []

    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,
        result_grouped,
        result_in_time,
        roi_grouped,
        roi_in_time,
    ) 


# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    plt.figure(figsize=(15, 10))

    retention = retention.drop(columns=['cohort_size', 0])
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    ax3 = plt.subplot(2, 2, 3)
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )

    
# функция для визуализации конверсии    

def plot_conversion(conversion, conversion_history, horizon, window=7):

    plt.figure(figsize=(15, 5))

    conversion = conversion.drop(columns=['cohort_size'])
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))


# функция для визуализации LTV и ROI    

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    plt.figure(figsize=(30, 15))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    cac_history = roi_history[['cac']]

    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    
# функция для сглаживания фрейма    

def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# # Шаг 3. Проведём исследовательский анализ данных
#
# Построим профили пользователей. Определим минимальную и максимальную дату привлечения пользователей.
#
# Выясним:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# Получим профили пользоваталей, применив фцнкцию `get_profiles`

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# Создадим на основе полученной таблицы ещё одну, на этот раз включающую в себя только платящих пользователей. Назовем её `payers`

# %%
payers = profiles[profiles['payer'] == True]

# %% [markdown]
# Получим минимальную и максимальную дату привлечения пользователей, воспользовавшись данными из таблицы `profiles`

# %%
print('Минимальная дата привлечения:', profiles['dt'].min().date())
print('Максимальная дата привлечения:', profiles['dt'].max().date())
# Out:
# Минимальная дата привлечения: 2019-05-01
# Максимальная дата привлечения: 2019-10-27

# %% [markdown]
# Отлично, даты соответствуют тем, что были в описании.

# %% [markdown]
# Выясним количество и долю платящих пользователей в разбивках по странам, устройствам и каналам. Построим таблицу, отражающую количество пользователей и долю платящих для каждой разбивки.

# %%
# функция для построения круговых диаграмм. В проекте в итоге не пригодилась :(

#def build_graphs(data, name, group_condition):
#    data = data.groupby(group_condition).agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
#    data.plot(kind='pie', 
#                    y='user_id', 
#                    autopct='%1.2f%%',
#                    wedgeprops={'linewidth': 1.5, 'edgecolor': 'white'},
#                    legend=False,
#                    title = f'Распределение пользователей по {name}',
#                    textprops={'fontsize': 12},
#                    shadow=True,
#                    ax=axes,
#                    pctdistance=0.7,
#                    explode = [el / 40 for el in range(0, len(data))]
#    ).set(ylabel='')

# %%
# сгруппируем два наших фрейма profiles и payers по региону, потом соединим их,
# чтобы было удобнее сранивать общее кол-во клиентов и платящих

profiles_grouped_by_region = profiles.groupby('region').agg({'user_id': 'count'}).sort_values(by='user_id')
payers_grouped_by_region = payers.groupby('region').agg({'user_id': 'count'}).sort_values(by='user_id')
total_grouped_by_region = profiles_grouped_by_region.merge(payers_grouped_by_region, on='region')
total_grouped_by_region = total_grouped_by_region.rename(columns={'user_id_x': 'total_clients', 'user_id_y': 'payers'})
total_grouped_by_region['ratio_pct'] = round(total_grouped_by_region['payers'] / total_grouped_by_region['total_clients'] * 100, 1)
total_grouped_by_region.sort_values(by='payers', ascending=False)
# Out:
#                total_clients  payers  ratio_pct
# region
# United States         100002    6902        6.9
# UK                     17575     700        4.0
# France                 17450     663        3.8
# Germany                14981     616        4.1

# %% [markdown]
# Похоже, основную долю клиентов составляют жители США. Доля платящих оттуда также заметно выше, чем из остальных стран.

# %%
# поступим аналогичным образом для разбивки по устройствам

profiles_grouped_by_device = profiles.groupby('device').agg({'user_id': 'count'}).sort_values(by='user_id')
payers_grouped_by_device = payers.groupby('device').agg({'user_id': 'count'}).sort_values(by='user_id')
total_grouped_by_device = profiles_grouped_by_device.merge(payers_grouped_by_device, on='device')
total_grouped_by_device = total_grouped_by_device.rename(columns={'user_id_x': 'total_clients', 'user_id_y': 'payers'})
total_grouped_by_device['ratio_pct'] = round(total_grouped_by_device['payers'] / total_grouped_by_device['total_clients'] * 100, 1)
total_grouped_by_device.sort_values(by='payers', ascending=False)
# Out:
#          total_clients  payers  ratio_pct
# device
# iPhone           54479    3382        6.2
# Android          35032    2050        5.9
# Mac              30042    1912        6.4
# PC               30455    1537        5.0

# %% [markdown]
# Здесь показатели более ровные, из того, что можно выделить:
# - Пользователей iPhone заметно больше, чем всех остальных по отдельности;
# - Доля платящих среди пользователей техники Apple выше, чем у остальных. Хуже всех дела обстоят с пользователями ПК.

# %%
# и, наконец, тем же способом сделаем разбивку по каналам

profiles_grouped_by_channel = profiles.groupby('channel').agg({'user_id': 'count'}).sort_values(by='user_id')
payers_grouped_by_channel = payers.groupby('channel').agg({'user_id': 'count'}).sort_values(by='user_id')
total_grouped_by_channel = profiles_grouped_by_channel.merge(payers_grouped_by_channel, on='channel')
total_grouped_by_channel = total_grouped_by_channel.rename(columns={'user_id_x': 'total_clients', 'user_id_y': 'payers'})
total_grouped_by_channel['ratio_pct'] = round(total_grouped_by_channel['payers'] / total_grouped_by_channel['total_clients'] * 100, 1)
total_grouped_by_channel.sort_values(by='payers', ascending=False)
# Out:
#                     total_clients  payers  ratio_pct
# channel
# FaceBoom                    29144    3557       12.2
# TipTop                      19561    1878        9.6
# organic                     56439    1160        2.1
# WahooNetBanner               8553     453        5.3
# AdNonSense                   3880     440       11.3
# RocketSuperAds               4448     352        7.9
# LeapBob                      8553     262        3.1
# OppleCreativeMedia           8605     233        2.7
# lambdaMediaAds               2149     225       10.5
# YRabbit                      4312     165        3.8
# MediaTornado                 4364     156        3.6

# %% [markdown]
# Кроме органики, у нас есть 2 канала, которые приносят больше всего пользователей: `FaceBoom` и `TipTop`. Конверсия у этих двух каналов также на высоком уровне.
#
# Есть ещё два канала с высокой долей платящих пользователей: `AdNonSense` и `lambdaMediaAds`.

# %% [markdown]
# # Шаг 4. Маркетинг
#
# Выясним:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг. Выясним, как траты распределены по источникам.

# %%
amount = round(profiles['acquisition_cost'].sum())
print(f'Общая сумма расходов на маркетинг с 05.01.2019 по 27.10.2019: {amount} у.е.')
# Out:
# Общая сумма расходов на маркетинг с 05.01.2019 по 27.10.2019: 105497 у.е.

# %%
profiles.groupby('channel').agg({'acquisition_cost': 'sum'}).sort_values(by='acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %% [markdown]
# Траты на рекламу в TipTop и FaceBoom резко выше, чем во всех остальных источниках, в сумме более 80 процентов расходов на маркетинг приходится на эти два канала. Особенно выделяется TipTop, траты на привлечение клиентов в котором почти в 2 раза превышают траты в FaceBoom и составляют более 50 процентов от общей суммы.
#
# Визуализируем изменение САС во времени.

# %%
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc={'acquisition_cost': 'sum'}
).plot(grid=True, figsize=(12, 6))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Очевидно, что траты на рекламу в TipTop и FaceBoom только растут, в то время как в остальных источниках всё более ровно. Кажется, у нас есть подозреваемые, хотя выводы делать рано.

# %%
# Узнаем, сколько в среднем денег потрачено на привлечение одного клиента

profiles['acquisition_cost'].mean()
# Out:
# 0.7032778251827625

# %% [markdown]
# 0.7 доллара - довольно много. Посмотрим в разбивке по каналам.

# %%
profiles.groupby('channel').agg({'acquisition_cost': 'mean'}).sort_values(by='acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %% [markdown]
# Цена одного привлеченного клиента в FaceBoom не сильно отличается от "среднего по палате". Чего нельзя сказать о цене в TipTop, которая выше в 2 с лишним раза и резко выделяется на фоне остальных.
#
# Время посмотреть средний ценник с разбивкой по каналам в динамике.

# %%
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(12, 6))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Вот оно! В то время, как во всех остальных источниках (в том числе в FaceBoom) показатели стабильные, средний чек за пользователя в TipTop растёт, причём растет резко и быстро. График ступенчатый, посмотрим, с чем это может быть связано.
#
# Промежуточный вывод:
#
# - 60-70 процентов всех наших пользователей - граждане США;
# - Примерно треть всех пользователей приходит из двух каналов: FaceBoom и TipTop. Скорее всего, проблему надо искать там;
# - Стоимость привлечения одного клиента в TipTop быстро растет: за полгода цена выросла в 3.5 раза. Однако количество и доля платящих пользователей, приходящих с этого источника, не так высоки. Это можно объяснить молодой адиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.

# %% [markdown]
# # Оценим окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируем общую окупаемость рекламы;
# - Проанализируем окупаемость рекламы с разбивкой по устройствам;
# - Проанализируем окупаемость рекламы с разбивкой по странам;
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишем проблемы, которые мы обнаружим. Ответим на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучим конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишем возможные причины обнаруженных проблем и сформируем рекомендации для рекламного отдела. Мы смотрим данные 1-го ноября 2019 года. Окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Проанализируем общую окупаемость рекламы
#
# Для этого рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`

# %%
# исходя из задания, задаем момент и горизонт анализа. Также уберем из `profiles` пользователей с органическим трафиком. 
# Для дальнейшего исследования они нам не понадобятся

profiles = profiles.query('channel != "organic"')

observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)


plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По этим графикам можно сделать следующие выводы:
#
# - Реклама не окупается. ROI на 14-й день - чуть более 80 процентов;
# - График динамики стоимости привлечения пользователей стремится вверх. Значит, рекламный бюджет увеличивается. Это наверняка связано с увеличением стоимости клиента в TipTop'е;
# - Динамика ROI отрицательная. И это логично, учитывая резкое увеличение расходов на рекламу.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по устройствам

# %%
dimensions=['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# По этим графикам видно, что пользователи техники apple в целом "хуже" остальных: реклама не окупается в основном за счет них. Также цена привлечения пользователя iPhone и Mac растет быстрее.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам

# %%
dimensions=['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Картина начинает складываться. Выводы пока такие:
#
# - LTV пользователей из США самый высокий;
# - Напротив, ROI пользователей из США самый низкий, причем с резким отрывом. Более того, реклама не окупается именно за счет них. Все остальные страны - в плюсе;
# - График динамики стоимости привлечения в разбивке по странам подозрительно напоминает то же график в разбивке по каналам. Судя по всему, аудитория TipTop - в основном жители США. Учитывая, какую долю всего нашего трафика они занимают, становится понятно, почему реклама не окупается: пользователи из США очень дорогие, и их большинство.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам

# %%
dimensions=['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Знакомая картина. Хотя LTV пользователей TipTop один из самых высоких, ROI самый низкий. Ответ - на графике динамики стоимости привлечения. Скорость повышения цены за клиента в TipTop вызывает благоговейный ужас.

# %% [markdown]
# ### Построим и изучим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам

# %% [markdown]
# Рассчитаем и визуализируем конверсию и удержание, применив функции `plot_conversion` и `plot_retention`

# %%
dimensions=['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Коверсия в разбивке по каналам в целом хорошая и стабильная.

# %%
dimensions=['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия в разбивке по устройствам также вопросов не вызывает.

# %%
dimensions=['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по этому графику, пользователи из США конвертируются, причем крайне хорошо. Посмотрим на удержание.

# %%
dimensions=['channel']

conversion_raw, conversion_grouped, conversion_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Вот и еще одна проблема: удержание пользователей, пришедших из FaceBoom, находится ниже "органики", и это плохой показатель.

# %%
dimensions=['device']

conversion_raw, conversion_grouped, conversion_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Удержание в разбивке по устройствам выглядит нормально.

# %%
dimensions=['region']

conversion_raw, conversion_grouped, conversion_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей из США ниже всех остальных. Посмотрим, какая доля пользователей из разных стран пользуется TipTop и FaceBoom, а также заходит с устройств Apple. Из того, что мы видели выше, есть подозрение, что и в том и другом случае на первых местах будут пользователи из США.
#
# Создадим датафреймы `usa_payers`, `german_payers`, `uk_payers` и `french_payers`, и сгруппируем их по каналам привлечения и устройствам.

# %%
usa_payers = payers[payers['region'] == 'United States']
display(usa_payers.groupby('channel').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False))
usa_payers.groupby('device').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False)
# Out:
#                          user_id
# channel
# FaceBoom        1801874552179937
# TipTop           932087707241321
# organic          384467365888561
# RocketSuperAds   177287644887685
# YRabbit           84375025470346
# MediaTornado      79568747062729
#                   user_id
# device
# iPhone   1506423338665074
# Mac       842829237395205
# Android   749905676974499
# PC        360502789695801

# %%
german_payers = payers[payers['region'] == 'Germany']
display(german_payers.groupby('channel').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False))
german_payers.groupby('device').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False)
# Out:
#                            user_id
# channel
# WahooNetBanner      75217255300189
# AdNonSense          72426340221829
# organic             63590596914259
# LeapBob             34964943135175
# lambdaMediaAds      31540984007884
# OppleCreativeMedia  29615009980940
#                  user_id
# device
# PC       130742401574013
# Android   91898941696509
# iPhone    57307894702138
# Mac       27405891587616

# %%
uk_payers = payers[payers['region'] == 'UK']
display(uk_payers.groupby('channel').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False))
uk_payers.groupby('device').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False)
# Out:
#                            user_id
# channel
# WahooNetBanner      80410991859783
# AdNonSense          72577570333981
# organic             63886658437718
# LeapBob             49078865131424
# OppleCreativeMedia  44516733523805
# lambdaMediaAds      39418834627034
#                  user_id
# device
# PC       147753056342289
# Android  103584067436185
# iPhone    64166883681356
# Mac       34385646453915

# %%
french_payers = payers[payers['region'] == 'France']
display(french_payers.groupby('channel').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False))
french_payers.groupby('device').agg({'user_id': 'sum'}).sort_values(by='user_id', ascending=False)
# Out:
#                            user_id
# channel
# WahooNetBanner      82077872573003
# AdNonSense          71789640848321
# organic             59420625389201
# LeapBob             43878622651070
# lambdaMediaAds      39174833323359
# OppleCreativeMedia  38108681920282
#                  user_id
# device
# PC       133840391438950
# Android   93281352922498
# iPhone    62793042972657
# Mac       44535489371131

# %% [markdown]
# Всё ещё интереснее, чем можно было предположить. Платформами TipTop и FaceBoom пользуются только пользователи из США. Это объясняет и растущую цену на привлечение (TipTop), и плохое удержание (FaceBoom) этих пользователей.
#
# Также раскрыта тайна плохих показателей для пользователей техники Apple: ими тоже пользуются в основном жители США.
#
# Как говорится, мы видели достаточно. Можно писать вывод.

# %% [markdown]
# # Шаг 6. Выводы
#
# Общий вывод:
#
# Итак, мы провели полноценный анализ данных о пользователях компании. Вот наши выводы и рекомендации:
#
# - Более `70` процентов платящих пользователей приходится на `США`;
# - Более `трети` платящих пользователей пользуются `iPhone`. Суммарно более `60` процентов платящих пользователей приходится на 2 канала привлечения - `TipTop` и `FaceBoom`. И первый и второй показатель следуют из первого пункта: жители США - единственные пользователи и TipTop, и FaceBoom. Также именно они предпочитают технику Apple.
# - Цена привлечения пользователя в TipTop сильно растет - всего за полгода она выросла в `3.5` раза. Учитывая, что наш основной рынок - пользователи из США, этот показатель можно назвать критическим.
# - Удержание пользователей `FaceBoom`, и, как следствие, пользователей из США, резко ниже, чем на остальных платформах. Необходимо разобраться, весьма вероятно, что мы имеем дело с технической ошибкой.
#
# Общая рекомендация:
#
# Рынок США - наша главная, пока что не реализованная, точка роста. С одной стороны, подавляющее большинство наших клиентов приходит именно оттуда, причем конверсия этих клиентов хорошая, т.е. потенциально это хорошие клиенты. Однако низкое удержание вкупе с огромной ценой привлечения одного такого клиента приводят сейчас к тому, что реклама не окупается именно благодаря клиентам из США. Убери их из уравнения - и мы выйдем в плюс.
# Стоит обратить внимание на следующие по популярности у пользователей из США платформы, напр. `RocketSuperAds` и `YRabbit`. Аудитория там не настолько большая, но цена привлечения, а ,как следствие, ROI пользователей с этих каналов гораздо выше.
